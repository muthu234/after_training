# %%
import pandas as pd
import numpy as np
sf_permits = pd.read_csv("Building_Permits.csv")
np.random.seed(1)
# Out:
# /tmp/ipykernel_73351/2965332303.py:3: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   sf_permits = pd.read_csv("Building_Permits.csv")

# %%
sf_permits.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
missing_value_count=sf_permits.isnull().sum()
print(missing_value_count)
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
total_cells = np.product(sf_permits.shape)
total_missing = missing_value_count.sum()
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
print(total_cells)
# Out:
# 26.26002315058403
# 8552700

# %%
sf_permits.dropna(axis=1)
column_with_dropna= sf_permits.dropna(axis=1)
print(column_with_dropna)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Name  \
# 0                05/06/2015  0326   023            140       Ellis
# ...

# %%
sf_permits.shape[1]
# Out:
# 43

# %%
column_with_dropna.shape[1]
# Out:
# 12

# %%
sf_permits.isnull().sum()
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
sf_permits['Lot'].head()
# Out:
# 0    023
# 1    007
# 2    203
# 3    011
# 4    001
# Name: Lot, dtype: object

# %%
sf_permits.loc[:,'Lot':] //using particular header 1
sf_permits['Lot']
# Out:
#          Lot  Street Number Street Number Suffix Street Name Street Suffix  \
# 0        023            140                  NaN       Ellis            St
# 1        007            440                  NaN       Geary            St
# 2        203           1647                  NaN     Pacific            Av
# 3        011           1230                  NaN     Pacific            Av
# 4        001            950                  NaN      Market            St
# ...      ...            ...                  ...         ...           ...
# 198895  017A           1228                  NaN  Montgomery            St
# 198896   014            580                  NaN        Bush            St
# 198897   019           1568                  NaN     Indiana            St
# 198898   029            795                  NaN      Sutter            St
# 198899   006            838                  NaN     Pacific            Av
#
# ...

# %%
import pandas as pd

# Create a DataFrame with missing values
data = {'A': [None, 2, None, 4,8], 'B': [None, 22, 33, None, 55]}
df = pd.DataFrame(data)

# Original DataFrame
print("Original DataFrame:")
print(df)

# Fill missing values using backfill
df_filled = df.fillna(method='bfill')

# DataFrame after filling missing values
print("\nDataFrame after backfill:")
print(df_filled)
# Out:
# Original DataFrame:
#      A     B
# 0  NaN   NaN
# 1  2.0  22.0
# 2  NaN  33.0
# 3  4.0   NaN
# 4  8.0  55.0
#
# DataFrame after backfill:
#      A     B
# 0  2.0  22.0
# 1  2.0  22.0
# 2  4.0  33.0
# 3  4.0  55.0
# 4  8.0  55.0

# %%
from art import *

ascii_art = text2art("John")
print(ascii_art)
# Out:
#      _         _
#     | |  ___  | |__   _ __
#  _  | | / _ \ | '_ \ | '_ \
# | |_| || (_) || | | || | | |
#  \___/  \___/ |_| |_||_| |_|

# %%
import pyfiglet

ascii_art = pyfiglet.figlet_format("John")
print(ascii_art)
# Out:
#      _       _
#     | | ___ | |__  _ __
#  _  | |/ _ \| '_ \| '_ \
# | |_| | (_) | | | | | | |
#  \___/ \___/|_| |_|_| |_|

# %%
import pygame

# Initialize pygame
pygame.init()

# Set up the display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("Graphical Text")

# Define colors
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)

# Define font
font = pygame.font.Font(None, 36)

# Define text and position
text = "Hello, World!"
text_render = font.render(text, True, WHITE)
text_rect = text_render.get_rect()
text_rect.center = (width // 2, height // 2)

# Main loop
running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    # Clear the screen
    screen.fill(BLACK)

    # Draw the text
    screen.blit(text_render, text_rect)

    # Update the display
    pygame.display.flip()

# Quit pygame
pygame.quit()
# Out:
# pygame 2.5.2 (SDL 2.28.2, Python 3.8.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import turtle

# Function to draw a star
def draw_star():
    star = turtle.Turtle()
    star.right(75)
    star.forward(100)
    for i in range(4):
        star.right(144)
        star.forward(100)
    turtle.done()

# Function to print a name with color
def print_name_with_color(name):
    colors = ["red", "green", "blue", "orange", "purple"]  # List of colors
    turtle.penup()
    turtle.goto(-200, 0)  # Starting position
    turtle.pendown()

    for char in name:
        color_index = ord(char) % len(colors)  # Calculate color index based on ASCII value of character
        turtle.color(colors[color_index])  # Set color
        turtle.write(char, font=("Arial", 24, "bold"))  # Write character
        turtle.forward(30)  # Move turtle forward

    turtle.done()

# Call function to print a name with color
print_name_with_color("John")

# %%
turtle.bgcolor("blue")
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 turtle.bgcolor("blue")
#
# File <string>:5, in bgcolor(*args)
#
# Terminator:

# %%
for i in range(20):
    if player_one.pos() >= (300,100):
            print("Player One Wins!")
            break
    elif player_two.pos() >= (300,-100):
            print("Player Two Wins!")
            break
    else:
            player_one_turn = input("Press 'Enter' to roll the die ")
            die_outcome = random.choice(die)
            print("The result of the die roll is: ")
            print(die_outcome)
            print("The number of steps will be: ")
            print(20*die_outcome)
            player_one.fd(20*die_outcome)
            player_two_turn = input("Press 'Enter' to roll the die ")
            die_outcome = random.choice(die)
            print("The result of the die roll is: ")
            print(die_outcome)
            print("The number of steps will be: ")
            print(20*die_outcome)
            player_two.fd(20*die_outcome)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 for i in range(20):
# ----> 2     if player_one.pos() >= (300,100):
#       3             print("Player One Wins!")
#       4             break
#
# NameError: name 'player_one' is not defined
